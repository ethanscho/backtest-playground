# %% [markdown]
# ## QP: PBR + GP/A

# %% [markdown]
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1   | 46.23% (41.77%) | 53.35% |      7       | 0.0959 (연단위: 0.4330) |    11    |  62.25%  |  2002 ~ 2019    |
# |    8-1    | 46.33% | 50.57% |      7       | 0.1362 |    7     |  62.08%  |  1999 ~ 2019    |
# |    8-1    | 41.36% | 58.71% |      8       | 0.1291 |    6     |  60.00%  |  유동비율 > 100%   |
# |    8-1    | 26.13% | 55.30% |      8       | 0.0836 |    4     |  59.17%  |  주당배당금 > 0    |
# |    9-1    | 37.03% | 55.96% |      10      | 0.1098 |    12    |  58.33%  |  1999 ~ 2019    |
# |    10-1   | 46.13% | 53.35% |      7       | 0.0963 |    13    |      | 2002 ~ 2019 |
# |    10-1   | 41.26% | 56.33% |      8       | 0.1183 |    11    |  59.17%  |  1999 ~ 2019    |
# |    2, 8월    | 51.29% (48.27%) | 43.77% |      18      | 0.3008 |    21    |  58.19%  |      |
# |  1-4-7-10 | 47.53% (41.71%) | 43.61% |      9       | 0.1732 |    39    |  55.92%  |      |
# |  2-5-8-11| 56.28% (50.12%) | 43.58% |      9       | 0.1936 |    54    |  55.16%  |      |
# |  3-6-9-12 | 45.14% (39.41%)| 57.08% |      12      | 0.2004 |    41    |  54.27%  |      |

# %% [markdown]
# ## Super value: PBR + PCR + PER + PSR

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    5-1    | 32.93% | 49.29% |      7       | 0.0849 |    4     |  60.29%  | 2002 ~ 2019 유동비율 150%     |
# |    6-1    | 34.20% | 50.27% |      6       | 0.0892 |    5     |  60.29%  | 2002 ~ 2019 유동비율 150%     |
# |    7-1    | 34.12% | 47.22% |      7       | 0.0816 |    4     |  61.76%  | 2002 ~ 2019 유동비율 150%     |
# |    8-1    | 29.76% | 64.58% |      8       | 0.0859 |    7     |  61.27%  | 2002 ~ 2019     |
# |    8-1    | 35.32% | 55.80% |      7       | 0.0880 |    5     |  62.25%  | 2002 ~ 2019 유동비율 150%     |
# |    9-1    | 29.40% | 52.33% |      8       | 0.0914 |    6     |  59.72%  | 2002 ~ 2019 유동비율 150%    |
# |    10-1   | 31.08% | 53.98% |      8       | 0.1152 |    7     |  59.17%  | 1999 ~ 2019 유동비율 100% 이상    |
# |    10-1   | 23.30% | 45.98% |      6       | 0.0968 |    6     |  57.92%  | 1999 ~ 2019 유동비율 200% 이상    |
# |    10-1   | 28.36% | 48.16% |      7       | 0.1046 |    5     |  58.33%  | 1999 ~ 2019 유동비율 150% 이상     |
# |    10-1   | 30.55% | 48.16% |      7       | 0.0847 |    5     |  58.82%  | 2002 ~ 2019     |
# |    11-1   | 26.80% | 49.96% |      6       | 0.0837 |    3     |  58.82%  | 2002 ~ 2019
# |  2-5-8-11 | 43.84% (38.17%) | 39.28% |      9       | 0.1678 |    37    |  55.54%  | 2002 ~ 2019     |
# |  1-4-7-10 | 36.97% (31.65%) | 42.51% |      12      | nan |    25    |  55.02%  | 2002 ~ 2019     |
# |  3-6-9-12 | 28.56% (23.49%) | 41.60% |      15      | 0.1475 |    26    |  54.23%  |      |

# %% [markdown]
# ## NCAV

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Note |
# |-|-|-|-|-|-|-|
# |    8-1    | 23.65% | 54.13% |      7       | 0.0793 |    4     |      |

# %% [markdown]
# ## Super quality: 증자 x, 당기순이익 +, 영업현금흐름 +, GP/A

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Note |
# |-|-|-|-|-|-|-|
# |    8-1    | 23.59% | 54.95% |      9       | 0.0764 |    11    |      |

# %% [markdown]
# ## Lu Zhang: 고 ROE + 저 자본총계 성장률

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 18.77% | 65.51% |      14      | 0.0900 |    9     |  57.89%  | 2000 ~ 2019     |
