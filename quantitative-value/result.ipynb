# %% [markdown]
# # PBR + GP/A

# %% [markdown]
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 43.21% | 13.05% |      1       | 0.4330 |    11    |  63.33%  |      |
# |    9-1    | 37.28% | 24.83% |      1       | 0.4014 |    14    |  62.04%  |      |
# |    10-1   | 42.15% | 24.40% |      1       | 0.4294 |    14    |  62.55%  |      |
# |    11-1   | 46.02% | 41.52% |      1       | 0.5087 |    7     |  64.90%  |      |
# |    8-1    | 38.87% | 15.55% |      1       | 0.3485 |    7     |  60.59%  | 2002 ~ 2019 유동비율 150%     |
# |    9-1    | 28.96% | 38.04% |      2       | 0.3237 |    9     |  59.44%  | 2002 ~ 2019 유동비율 150%     |
# |    10-1   | 35.78% | 23.70% |      1       | 0.4741 |    8     |  60.98%  | 2002 ~ 2019 유동비율 150%     |
# |    11-1   | 37.63% | 40.39% |      1       | 0.6448 |    5     |  61.76%  | 2002 ~ 2019 유동비율 150%     |
# |  2-5-8-11 | 56.28% | 43.58% |      9       | 0.1936 |    54    |  55.16%  | 2002 ~ 2019 분기단위 백테스트    |
# |  2-5-8-11 | 46.56% | 40.24% |      9       | 0.2028 |    39    |  54.18%  | 2002 ~ 2019 분기단위 백테스트 / 유동비율 > 150%     |
#
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1   | 46.23% (41.77%) | 53.35% |      7       | 0.0959 (연단위: 0.4330) |    11    |  62.25%  |  2002 ~ 2019 월단위 백테스트   |
# |    8-1    | 46.33% | 50.57% |      7       | 0.1362 |    7     |  62.08%  |  1999 ~ 2019    |
# |    8-1    | 41.36% | 58.71% |      8       | 0.1291 |    6     |  60.00%  |  유동비율 > 100%   |
# |    8-1    | 26.13% | 55.30% |      8       | 0.0836 |    4     |  59.17%  |  주당배당금 > 0    |
# |    9-1    | 37.03% | 55.96% |      10      | 0.1098 |    12    |  58.33%  |  1999 ~ 2019    |
# |    10-1   | 46.13% | 53.35% |      7       | 0.0963 |    13    |      | 2002 ~ 2019 |
# |    10-1   | 41.26% | 56.33% |      8       | 0.1183 |    11    |  59.17%  |  1999 ~ 2019    |
# |    2, 8월    | 51.29% (48.27%) | 43.77% |      18      | 0.3008 |    21    |  58.19%  |      |
# |  1-4-7-10 | 47.53% (41.71%) | 43.61% |      9       | 0.1732 |    39    |  55.92%  |      |
# |  2-5-8-11| 56.28% (50.12%) | 43.58% |      9       | 0.1936 |    54    |  55.16%  |      |
# |  3-6-9-12 | 45.14% (39.41%)| 57.08% |      12      | 0.2004 |    41    |  54.27%  |      |
#
#
# 2002 ~ 2019 / 지주사, 금융사 제외
#
# | 시총 |0~20|20~40|40~60|60~80|80~100|
# |-|-|-|-|-|-|
# |CAGR|43.21%|17.50%|13.44%|11.24%|11.64%|

# %% [markdown]
# - 2002 ~ 2019
# - 매년 11/1 리밸런싱
# - 모델: (PBR + GP/A) + 지수 인버스
# - 인버스는 KODEX200 수익률의 역수로 가정 (지수 인버스 ETF들 중 가장 오래된 것이 2010년부터이기 떄문)
#
# | Inverse hedge ratio |  CAGR (거래비용 1%)  |  MDD    |  STD   | 수익이 난 해 (%) | Note |
# |-|-|-|-|-|-|
# |    0.0    | 44.56% | 42.10%        | 0.4330     |  88.23%  |      |
# |    0.2    | 36.38% | 19.46%        | 0.4013     |  88.23%  |      |
# |    0.25    | 34.11% | 13.80%        | 0.3761     |  88.23%  |      |
# |    0.3    | 31.75% | 10.59%        | 0.3459     |  88.23%  |      |
# |    0.4    | 26.81% | 12.38%        | 0.2804     |  94.11%  |      |
# |    0.5    | 21.57% | 14.17%        | 0.2213     |  76.47%  |      |
# |    0.6    | 16.03% | 15.96%        | 0.1748     |  76.47%  |      |
# |    0.7    | 10.18% | 17.76%        | 0.1532     |  70.58%  |      |
# |    0.8    | 3.97% | 25.28%        | 0.1383    |  52.94%  |      |
# |    1.0    | -9.81% | 80.29%        | 0.1481     |  17.64%  |      |

# %% [markdown]
# N년 후 연평균 수익률 (CAGR)이 40%를 넘을 확률:
# 0.65
# 0.56
# 0.73
# 0.71
# 0.69
# 0.75
# 0.82
# 0.90
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# --> 8년

# %% [markdown]
# N년 후 연평균 수익률 (CAGR)이 30%를 넘을 확률:
# 0.65
# 0.75
# 0.87
# 0.86
# 0.85
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00 --> 6년

# %% [markdown]
# N년 후 연평균 수익률 (CAGR)이 20%를 넘을 확률:
#     0.65
# 0.81
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00 --> 3년

# %% [markdown]
# # QP Monte-Carlo

# %% [markdown]
# | Dropouts | Simulations | CAGR Mean | CAGR STD |
# |-|-|-|-|
# |20%|100|0.4215|0.0259|
#
# 95.4% - 0.3697 ~ 0.4733

# %% [markdown]
# ## PBR + PCR + PER + PSR

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 34.86% | 7.95% |      1       | 0.2950 |    8     |  62.35%  | 2002 ~ 2019 유동비율 150%     |
# |    9-1    | 27.40% | 18.81% |      1       | 0.2638 |    7     |  59.81%  | 2002 ~ 2019 유동비율 150%     |
# |    10-1   | 30.62% | 23.56% |      1       | 0.3360 |    6     |  62.75%  | 2002 ~ 2019 유동비율 150%     |
# |    11-1   | 28.63% | 43.47% |      1       | 0.3620 |    4     |  62.35%  | 2002 ~ 2019 유동비율 150%     |
# |    12-1   | 27.02% | 31.41% |      1       | 0.2867 |    3     |  62.16%  | 2002 ~ 2019 유동비율 150%     |

# %% [markdown]
# | Dropouts | Simulations | CAGR Mean | CAGR STD |
# |-|-|-|-|
# |20%|100|0.3369|0.0207|
#
# 95.4% - 0.2955 ~ 0.3783

# %% [markdown]
# ## GP/A (매출총이익/자산총계)
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 44.02% | 13.89% |      1       | 0.3942 |    17    |  53.92%  | 2002 ~ 2019, 지주사, 금융 제외     |

# %% [markdown]
# ## PBR
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 56.43% | 0.00% |      0       | 0.4815 |    22    |  61.37%  | 2002 ~ 2019     |
# |    8-1    | 57.78% | 0.00% |      0       | 0.4781 |    22    |  61.96%  |  2002 ~ 2019, 지주사, 금융 제외    |
# |    8-1    | 35.19% | 12.92% |      2       | 0.3474 |    12    |  62.16%  | 2002 ~ 2019 유동비율 150%     |
# |    8-1    | 34.70% | 24.22% |      2       | 0.3542 |    11    |  62.55%  | 2002 ~ 2019 유동비율 150%, 지주사, 금융 제외     |

# %% [markdown]
# ## PCR
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 32.16% | 8.78% |      1       | 0.3336 |    9     |  58.43%  | 2002 ~ 2019 유동비율 150%     |

# %% [markdown]
# ## PER
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 28.30% | 26.97% |      1       | 0.3524 |    12    |  58.43%  | 2002 ~ 2019 유동비율 150%     |

# %% [markdown]
# ## PSR
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 41.40% | 0.00% |      0       | 0.2892 |    8     |  60.00%  | 2002 ~ 2019 유동비율 150%     |
# |    8-1    | 42.06% | 0.00% |      0       | 0.2821 |    7     |  60.59%  | 2002 ~ 2019 유동비율 150%, 지주사, 금융 제외     |
# |    8-1    | 48.80% | 7.39% |      1       | 0.6090 |    23    |  57.65%  | 2002 ~ 2019 매출액 YoY 높은 순서     |
# |    8-1    | 48.80% | 7.39% |      1       | 0.6090 |    23    |  57.65%  |      |

# %% [markdown]
# ## PBR + PSR
#
# | Rebalance |  CAGR (슬리피지 1%)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    5-1    | 28.19% | 19.10% |      1       | 0.4157 |    35    |  61.57%  | 2002 ~ 2019     |
# |    6-1    | 37.63% | 19.49% |      1       | 0.5517 |    19    |  60.59%  | 2002 ~ 2019     |
# |    7-1    | 51.65% | 12.72% |      1       | 0.4992 |    15    |  63.73%  | 2002 ~ 2019     |
# |    8-1    | 56.51% | 0.00% |      0       | 0.6049 |    16    |  62.35%  | 2002 ~ 2019     |
# |    9-1    | 43.89% | 23.61% |      1       | 0.4370 |    26    |  58.89%  | 2002 ~ 2019     |
# |    10-1   | 50.80% | 24.92% |      1       | 0.5039 |    27    |  58.24%  | 2002 ~ 2019     |
# |    11-1   | 43.84% | 44.05% |      2       | 0.5678 |    22    |  60.78%  | 2002 ~ 2019     |
# |    12-1   | 35.86% | 44.39% |      1       | 0.3194 |    21    |  60.20%  | 2002 ~ 2019     |
# |    8-1    | 36.86% | 8.82% |      1       | 0.3319 |    9     |  61.96%  | 2002 ~ 2019 유동비율 150%     |
# |    9-1    | 32.32% | 22.30% |      1       | 0.3153 |    7     |  59.81%  | 2002 ~ 2019 유동비율 150%     |
# |    10-1   | 39.76% | 24.94% |      1       | 0.4121 |    10    |  62.35%  | 2002 ~ 2019 유동비율 150%     |
# |    11-1   | 40.13% | 39.86% |      1       | 0.4030 |    5     |  64.31%  | 2002 ~ 2019 유동비율 150%     |
# |    12-1   | 34.23% | 42.57% |      1       | 0.3291 |    6     |  62.16%  | 2002 ~ 2019 유동비율 150%    |
# |    8-1    | 56.22% | 0.00% |      0       | 0.6035 |    15    |  61.96%  | 2002 ~ 2019 지주사 금융사 제외, 30종목     |
# |    8-1    | 56.80% | 11.29% |      1       | 0.6025 |    10    |  60.88%  | 2002 ~ 2019 지주사 금융사 제외, 20종목     |
# |    8-1    | 37.34% | 11.09% |      1       | 0.3627 |    8     |  62.35%  | 2002 ~ 2019 유동비율 150% 지주사 금융사 제외     |
# |  2-5-8-11 | 61.13% | 40.65% |      9       | 0.2310 |    64    |  54.55%  | 2002 ~ 2019     |
# |  2-5-8-11 | 59.46% | 39.91% |      9       | 0.2293 |    63    |  54.13%  | 2002 ~ 2019 지주사 금융사 제외     |
# |  2-5-8-11 | 71.60% | 39.18% |      6       | 0.2232 |    31    |  56.43%  | 2002 ~ 2019 유동비율 150%     |
# |  2-5-8-11 | 73.67% (66.82%) | 38.89% |      6       | 0.2243 |    31    |  56.76%  | 2002 ~ 2019 유동비율 150%  지주사 금융사 제외     |
#
#
# 매년 8/1 리밸런싱 / 2002 ~ 2019 / 유동비율 150%
#
# | 시총 |0~20|20~40|40~60|60~80|80~100|
# |-|-|-|-|-|-|
# |CAGR|36.86%|14.96%|10.07%|11.47%|10.44%|

# %% [markdown]
# N년 후 연평균 수익률 (CAGR)이 X%를 넘을 확률:

# %% [markdown]
# 20%: 5년
# 0.71
# 0.69
# 0.87
# 0.86
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
#
# 30%: 8년
# 0.59
# 0.56
# 0.67
# 0.71
# 0.85
# 0.75
# 0.91
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00
# 1.00

# %% [markdown]
# 유동비율 150% 필터를 넣어야 상폐/거래정지 숫자가 절반 이하로 줄어든다. 분기별 리밸런싱, 시간을 단축하는데 큰 도움이 된다.
# 또한 유동비율 필터가 들어갔을 때 구간별 수익률 편차가 적다. CAGR 약 35% 모델로 보인다.

# %% [markdown]
# PBR+GPA / PBR+PSR 모델의 pearson coefficient = 0.67741997

# %% [markdown]
# ## NCAV
#
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Note |
# |-|-|-|-|-|-|-|
# |    8-1    | 23.65% | 54.13% |      7       | 0.0793 |    4     |      |

# %% [markdown]
# ## Super quality: 증자 x, 당기순이익 +, 영업현금흐름 +, GP/A

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Note |
# |-|-|-|-|-|-|-|
# |    8-1    | 23.59% | 54.95% |      9       | 0.0764 |    11    |      |

# %% [markdown]
# ## Lu Zhang: 고 ROE + 저 자본총계 성장률

# %% [markdown]
# | Rebalance |  CAGR  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 18.77% | 65.51% |      14      | 0.0900 |    9     |  57.89%  | 2000 ~ 2019     |

# %% [markdown]
# # PBR + 영업이익/자본총계
#
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    11-1   | 34.72% | 50.33% |      1       | 0.4116 |    9     |  62.55%  |      |
# |    10-1   | 38.05% | 30.33% |      1       | 0.4183 |    10    |  61.57%  |      |
# |    9-1    | 33.90% | 23.30% |      2       | 0.3370 |    11    |  60.93%  |      |

# %% [markdown]
# # PBR + 영업이익/자산총계
#
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    11-1   | 29.97% | 49.33% |      1       | 0.4271 |    9     |  63.14%  |      |
# |    10-1   | 31.95% | 28.36% |      1       | 0.4233 |    8     |  61.37%  |      |
# |    9-1    | 31.63% | 21.98% |      2       | 0.3428 |    10    |  62.96%  |      |

# %% [markdown]
# # PEG (PER/당기순이이익 YoY)
#
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 20.15% | 25.76% |      2       | 0.3862 |    15    |  57.65%  |  PER > 0    |

# %% [markdown]
# # Walter Scholoss 계량화
#
# - 유동자산 - 유동부채 > 시가총액 30%
# - 부채비율 (부채총계/자본총계) < 100%
# - 유동비율 (유동자산/유동부채)> 200%
# - PBR < 0.8
# - PBR 역수
#
# | Rebalance |  CAGR (수수료포함)  |  MDD   | MDD duration |  STD   | Delisted | Win rate | Note |
# |-|-|-|-|-|-|-|-|
# |    8-1    | 22.71% | 26.76% |      2       | 0.2971 |    8     |  55.69%  |      |
