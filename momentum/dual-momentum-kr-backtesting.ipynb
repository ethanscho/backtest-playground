# %%
from matplotlib import pyplot as plt
import FinanceDataReader as fdr
import pandas as pd

# %%
symbols = ['195930', # 유로스탁스 50
           '219480', # S&P 500
           '069500', # KODEX 200
           '101280', # KODEX JAPAN 
          ]

# %%
dfs = {}
for symbol in symbols:
    df = fdr.DataReader(symbol, '2001-06-01', '2020-06-01')
    dfs[symbol] = df
    print(symbol, "appended")
# Out:
# 195930 appended
# 219480 appended
# 069500 appended
# 101280 appended

# %%
dfs['101280']
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2008-02-20   8660   8665   8400   8450   37448       NaN
# 2008-02-21   8550   8690   8450   8570   22683  0.014201
# 2008-02-22   8500   8570   8440   8560    6421 -0.001167
# 2008-02-25   8800   8820   8590   8745   14469  0.021612
# 2008-02-26   8950   9005   8705   8715   18733 -0.003431
# ...           ...    ...    ...    ...     ...       ...
# 2020-05-26  13505  13710  13505  13690    3416  0.013699
# 2020-05-27  13690  13895  13690  13895    2374  0.014974
# 2020-05-28  13970  14240  13970  14220    8269  0.023390
# 2020-05-29  14220  14220  14060  14130    3950 -0.006329
# 2020-06-01  14150  14150  13905  13980    5403 -0.010616
#
# [3037 rows x 6 columns]

# %%
# 시작 날짜 통일
start_dates = []
for symbol, df in dfs.items():
    start_dates.append(df.index[0])
start_date = max(start_dates)
print(start_dates)

for symbol, df in dfs.items():
    dfs[symbol] = df[df.index >= start_date]
    print(symbol, dfs[symbol].index[0])
# Out:
# [Timestamp('2014-04-30 00:00:00'), Timestamp('2015-05-29 00:00:00'), Timestamp('2002-10-14 00:00:00'), Timestamp('2008-02-20 00:00:00')]
# 195930 2015-05-29 00:00:00
# 219480 2015-05-29 00:00:00
# 069500 2015-05-29 00:00:00
# 101280 2015-05-29 00:00:00

# %%
# 월별 데이터로 변환
timestamp_to_month = lambda x: x.strftime('%Y-%m')
f = {'High':'max', 'Low':'min', 'Open':'first', 'Close':'last', 'Volume':'sum'}

for symbol, df in dfs.items():
    df = df.groupby(df.index.map(timestamp_to_month)).agg(f)
    dfs[symbol] = df
    print(symbol, "converted")
# Out:
# 195930 converted
# 219480 converted
# 069500 converted
# 101280 converted

# %%
dfs['101280'].head(3)
# Out:
#           High    Low   Open  Close  Volume
# Date
# 2015-05  11160  10990  11045  11160     926
# 2015-06  11100  10650  11100  10965   24828
# 2015-07  11630  10550  11150  11430   44632

# %% [markdown]
# # Backtesting

# %%
df_account = pd.DataFrame(index=dfs['195930'].index).reset_index()

# %%
df_account
# Out:
#        Date
# 0   2015-05
# 1   2015-06
# 2   2015-07
# 3   2015-08
# 4   2015-09
# ..      ...
# 57  2020-02
# 58  2020-03
# 59  2020-04
# 60  2020-05
# 61  2020-06
#
# [62 rows x 1 columns]

# %%
# 6개월 수익률을 월마다 구하기
WINDOW_SIZE = 6

for symbol in symbols:
    df_account[symbol] = 0.0

# %%
for i in range (len(df_account)):
    if i < WINDOW_SIZE:
        continue
    
    for symbol in symbols:
        now = dfs[symbol].iloc[i].Open
        past = dfs[symbol].iloc[i-WINDOW_SIZE].Open
        yield_rate = now / past
        df_account.at[i, symbol] = yield_rate

# %%
df_account
# Out:
#        Date    195930    219480    069500    101280
# 0   2015-05  0.000000  0.000000  0.000000  0.000000
# 1   2015-06  0.000000  0.000000  0.000000  0.000000
# 2   2015-07  0.000000  0.000000  0.000000  0.000000
# 3   2015-08  0.000000  0.000000  0.000000  0.000000
# 4   2015-09  0.000000  0.000000  0.000000  0.000000
# ..      ...       ...       ...       ...       ...
# 57  2020-02  1.059932  1.084829  1.081356  1.087646
# 58  2020-03  0.983058  0.999282  1.061915  1.026792
# 59  2020-04  0.774906  0.853830  0.875163  0.903909
# 60  2020-05  0.794840  0.917732  0.932768  0.921015
# 61  2020-06  0.834998  0.962716  0.980600  1.000707
#
# [62 rows x 5 columns]

# %%
# def get_symbol(x):
#     max_yield = -1.0
#     under_deposit_interest = True
    
#     for symbol in symbols:
#         if x[symbol] < 1.01: # 5개 EFT 중 하나라도 수익률이 마이너스이면 IEF로 선택
#             under_deposit_interest *= True
#         else:
#             under_deposit_interest *= False
            
#         if x[symbol] > max_yield:
#             max_symbol = symbol
#             max_yield = x[symbol]
            
#     if under_deposit_interest:
#         return 'CASH'
#     else:
#         return max_symbol

# %%
def get_symbol(x):
    max_yield = -1.0
    for symbol in symbols:
        if x[symbol] < 1.0: # 5개 EFT 중 하나라도 수익률이 마이너스이면 IEF로 선택
            return 'CASH' 
            
        if x[symbol] > max_yield:
            max_symbol = symbol
            max_yield = x[symbol]

    return max_symbol

# %%
df_account['SYMBOL'] = df_account.apply(lambda x: get_symbol(x), axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_account
# Out:
#        Date    195930    219480    069500    101280  SYMBOL       MUL  \
# 6   2015-11  0.920796  0.979990  0.967213  0.956994    CASH  1.000000
# 7   2015-12  0.974870  0.989453  0.945946  0.972973    CASH  1.000000
# 8   2016-01  0.957842  0.998462  0.965707  0.979821    CASH  1.000000
# 9   2016-02  0.838627  0.919880  0.971223  0.911765    CASH  1.000000
# 10  2016-03  0.910355  1.025303  1.047146  0.953327    CASH  1.030988
# 11  2016-04  0.943415  1.093192  1.054868  0.956055    CASH  1.011230
# 12  2016-05  0.914903  0.994385  0.994085  0.955535    CASH  1.000000
# 13  2016-06  0.894667  1.014213  1.004492  0.982407    CASH  0.984985
# 14  2016-07  0.876006  1.017976  1.024962  0.916247    CASH  1.028968
# 15  2016-08  0.991812  1.127382  1.085810  0.997556    CASH  1.000966
# 16  2016-09  1.035808  1.105150  1.071227  1.014057  219480  0.989806
# 17  2016-10  1.007756  1.047984  1.055201  1.074055  101280  1.049453
# 18  2016-11  1.001508  1.042094  1.046399  1.094059  101280  1.016290
# 19  2016-12  0.982116  1.053053  1.050403  1.049482    CASH  1.022338
# 20  2017-01  1.150189  1.081231  1.078165  1.157343  101280  0.989642
# 21  2017-02  1.084623  1.053597  1.083111  1.108770  101280  0.996907
# 22  2017-03  1.115913  1.113107  1.082444  1.094646  195930  1.030068
# 23  2017-04  1.169831  1.102289  1.108487  1.057061  195930  1.019737
# 24  2017-05  1.193273  1.128079  1.149871  1.026697  195930  0.985696
# 25  2017-06  1.182600  1.099335  1.221484  1.035025  069500  1.025236
# 26  2017-07  1.067168  1.085861  1.212681  1.033664  069500  1.005327
# 27  2017-08  1.080875  1.085701  1.173068  1.055236  069500  0.981465
# 28  2017-09  1.026424  1.035325  1.144193  1.039301  069500  1.025520
# 29  2017-10  1.029825  1.077331  1.147107  1.120108  069500  1.038040
# 30  2017-11  1.017249  1.080786  1.170966  1.126928  069500  0.966595
# 31  2017-12  1.011976  1.098141  1.072118  1.092842  219480  1.016142
# 32  2018-01  1.020687  1.103567  1.052523  1.050522  219480  1.057243
# 33  2018-02  1.045335  1.149008  1.079077  1.106784  219480  0.964364
# 34  2018-03  1.004439  1.082561  1.016487  1.098739  101280  0.961759
# 35  2018-04  0.924191  1.034454  0.995942  1.010442    CASH  1.015464
# 36  2018-05  0.961952  1.027475  0.969904  1.000782    CASH  1.025954
# 37  2018-06  0.951817  1.022441  0.967553  1.017864    CASH  1.006546
# 38  2018-07  0.969383  1.015187  0.924599  1.027822    CASH  1.003094
# 39  2018-08  0.982737  0.993387  0.897098  0.999622    CASH  1.000000
# 40  2018-09  1.007070  1.084047  0.969724  0.988145    CASH  1.002872
# 41  2018-10  1.050691  1.111023  0.957962  1.060016    CASH  0.922198
# 42  2018-11  0.912726  1.021235  0.825682  0.976944    CASH  1.011167
# 43  2018-12  0.938721  1.031960  0.889886  0.973479    CASH  0.889925
# 44  2019-01  0.881673  0.921366  0.897532  0.889404    CASH  1.000000
# 45  2019-02  0.904456  0.954512  0.978303  0.923543    CASH  1.000000
# 46  2019-03  0.963581  0.966260  0.971636  0.950077    CASH  1.000000
# 47  2019-04  0.969298  0.973590  0.941282  0.937008    CASH  1.000000
# 48  2019-05  1.098446  1.077012  1.091728  1.036400  195930  0.950257
# 49  2019-06  1.028855  0.978358  0.971227  1.038862    CASH  0.982646
# 50  2019-07  1.172048  1.179434  1.064056  1.109130  219480  1.019767
# 51  2019-08  1.106585  1.100736  0.927143  1.084836    CASH  0.985445
# 52  2019-09  1.048270  1.035290  0.907653  1.079430    CASH  1.032830
# 53  2019-10  1.085520  1.043255  0.985562  1.095238    CASH  1.010230
# 54  2019-11  1.047170  1.034322  0.978445  1.079892    CASH  1.010365
# 55  2019-12  1.150805  1.145690  1.064150  1.090629  195930  1.018378
# 56  2020-01  1.087817  1.092481  1.068414  1.105449  101280  1.021277
# 57  2020-02  1.059932  1.084829  1.081356  1.087646  101280  0.922543
# 58  2020-03  0.983058  0.999282  1.061915  1.026792    CASH  0.881456
# 59  2020-04  0.774906  0.853830  0.875163  0.903909    CASH  1.000000
# 60  2020-05  0.794840  0.917732  0.932768  0.921015    CASH  1.000000
# 61  2020-06  0.834998  0.962716  0.980600  1.000707    CASH  1.000000
#
#      CUMPROD
# 6   1.000000
# 7   1.000000
# 8   1.000000
# 9   1.000000
# 10  1.030988
# 11  1.042566
# 12  1.042566
# 13  1.026912
# 14  1.056660
# 15  1.057680
# 16  1.046898
# 17  1.098670
# 18  1.116567
# 19  1.141510
# 20  1.129686
# 21  1.126191
# 22  1.160054
# 23  1.182950
# 24  1.166029
# 25  1.195455
# 26  1.201823
# 27  1.179548
# 28  1.209650
# 29  1.255666
# 30  1.213720
# 31  1.233312
# 32  1.303910
# 33  1.257445
# 34  1.209359
# 35  1.228060
# 36  1.259933
# 37  1.268181
# 38  1.272104
# 39  1.272104
# 40  1.275757
# 41  1.176501
# 42  1.189638
# 43  1.058689
# 44  1.058689
# 45  1.058689
# 46  1.058689
# 47  1.058689
# 48  1.006027
# 49  0.988568
# 50  1.008109
# 51  0.993437
# 52  1.026051
# 53  1.036548
# 54  1.047291
# 55  1.066538
# 56  1.089231
# 57  1.004862
# 58  0.885741
# 59  0.885741
# 60  0.885741
# 61  0.885741

# %%
len(df_account[df_account.SYMBOL == 'CASH']) / len(df_account)
# Out:
# 0.3064516129032258

# %%
def get_multiple(x):
    symbol = x.SYMBOL
    
    if symbol == 'CASH':
        return 1.0
    
    open_price = dfs[symbol].loc[x.Date, 'Open']
    close_price = dfs[symbol].loc[x.Date, 'Close']
    return close_price / open_price

# %%
df_account['MUL'] = df_account.apply(lambda x: get_multiple(x), axis=1)

# %%
df_account
# Out:
#        Date    195930    219480    069500    101280  SYMBOL       MUL
# 0   2015-05  0.000000  0.000000  0.000000  0.000000    CASH  1.000000
# 1   2015-06  0.000000  0.000000  0.000000  0.000000    CASH  1.000000
# 2   2015-07  0.000000  0.000000  0.000000  0.000000    CASH  1.000000
# 3   2015-08  0.000000  0.000000  0.000000  0.000000    CASH  1.000000
# 4   2015-09  0.000000  0.000000  0.000000  0.000000    CASH  1.000000
# ..      ...       ...       ...       ...       ...     ...       ...
# 57  2020-02  1.059932  1.084829  1.081356  1.087646  101280  0.922543
# 58  2020-03  0.983058  0.999282  1.061915  1.026792  069500  0.881456
# 59  2020-04  0.774906  0.853830  0.875163  0.903909    CASH  1.000000
# 60  2020-05  0.794840  0.917732  0.932768  0.921015    CASH  1.000000
# 61  2020-06  0.834998  0.962716  0.980600  1.000707    CASH  1.000000
#
# [62 rows x 7 columns]

# %%
df_account = df_account[WINDOW_SIZE:]

# %%
df_account['CUMPROD'] = df_account['MUL'].cumprod()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_account.tail(1)
# Out:
#        Date    195930    219480  069500    101280 SYMBOL  MUL   CUMPROD
# 61  2020-06  0.834998  0.962716  0.9806  1.000707   CASH  1.0  0.885741

# %%
plt.plot(df_account['Date'], df_account['CUMPROD'])
plt.show()

# %%
plt.plot(dfs['195930'].Close)
plt.show()

# %%
plt.plot(dfs['069500'].Close)
plt.show()
